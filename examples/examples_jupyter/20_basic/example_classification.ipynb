# %%
# %matplotlib inline

# %% [markdown]
# # Classification
#
# The following example shows how to fit a simple classification model with
# *auto-sklearn*.

# %%
from pprint import pprint

import sklearn.datasets
import sklearn.metrics
from sklearn import model_selection
import autosklearn.classification

# %% [markdown]
# ## Data Loading

# %%
X, y = sklearn.datasets.load_breast_cancer(return_X_y=True)
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(
    X, y, random_state=1
)

# %% [markdown]
# ## Build and fit a classifier

# %%
automl = autosklearn.classification.AutoSklearnClassifier(
    time_left_for_this_task=120,
    per_run_time_limit=30,
    memory_limit=16384,
    tmp_folder="/tmp/autosklearn_classification_example_tmp",
)
automl.fit(X_train, y_train, dataset_name="breast_cancer")
# Out:
# AutoSklearnClassifier(ensemble_class=<class 'autosklearn.ensembles.ensemble_selection.EnsembleSelection'>,
#                       memory_limit=16384, per_run_time_limit=30,
#                       time_left_for_this_task=120,
#                       tmp_folder='/tmp/autosklearn_classification_example_tmp')

# %% [markdown]
# ## View the models found by auto-sklearn

# %%
print(automl.leaderboard())
# Out:
#           rank  ensemble_weight                type      cost  duration
# model_id
# 88           2             0.06         extra_trees  0.007092  1.413559
# 94           3             0.04         extra_trees  0.007092  0.892238
# 108          1             0.12         extra_trees  0.007092  1.415933
# 7            4             0.02         extra_trees  0.014184  0.449032
# 27           8             0.04         extra_trees  0.014184  0.687339
# 54           7             0.04         extra_trees  0.014184  0.898463
# 75           6             0.04          libsvm_svc  0.014184  0.354724
# 80           5             0.02         extra_trees  0.014184  0.486883
# 21          11             0.02         extra_trees  0.021277  0.403240
# 30          12             0.02         extra_trees  0.021277  5.049771
# 35          13             0.02                 lda  0.021277  0.273900
# 73          10             0.02            adaboost  0.021277  0.622366
# 85           9             0.04         extra_trees  0.021277  0.517335
# 3           16             0.06                 mlp  0.028369  0.337192
# 6           21             0.02                 mlp  0.028369  0.361077
# 10          20             0.04       random_forest  0.028369  0.549744
# 11          19             0.02       random_forest  0.028369  0.642833
# 13          18             0.02   gradient_boosting  0.028369  0.457493
# 22          17             0.02   gradient_boosting  0.028369  0.345621
# 48          22             0.06         extra_trees  0.028369  0.438820
# 53          15             0.04                 lda  0.028369  0.250512
# 86          14             0.02         extra_trees  0.028369  0.463655
# 8           28             0.02       random_forest  0.035461  0.548845
# 18          23             0.02       random_forest  0.035461  0.549470
# 47          29             0.02                 lda  0.035461  0.333193
# 57          24             0.06         extra_trees  0.035461  0.700830
# 60          25             0.02  passive_aggressive  0.035461  0.316001
# 61          26             0.02                 qda  0.035461  0.290939
# 71          27             0.02  passive_aggressive  0.035461  0.314816
# 9           30             0.02         extra_trees  0.042553  0.515718

# %% [markdown]
# ## Print the final ensemble constructed by auto-sklearn

# %%
pprint(automl.show_models(), indent=4)
# Out:
# {   3: {   'balancing': Balancing(random_state=1),
#            'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x75ade9a3b490>,
#            'cost': 0.028368794326241176,
#            'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x75adf1e73f10>,
#            'ensemble_weight': 0.06,
#            'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x75ade9a3bc40>,
#            'model_id': 3,
#            'rank': 1,
#            'sklearn_classifier': MLPClassifier(activation='tanh', alpha=0.0001363185819149026, beta_1=0.999,
#               beta_2=0.9, early_stopping=True,
#               hidden_layer_sizes=(115, 115, 115),
#               learning_rate_init=0.00018009776276177523, max_iter=32,
#               n_iter_no_change=32, random_state=1, verbose=0, warm_start=True)},
#     6: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#            'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x75ade9c5c070>,
#            'cost': 0.028368794326241176,
#            'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x75adf22c5c70>,
#            'ensemble_weight': 0.02,
#            'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x75ade9c5c970>,
#            'model_id': 6,
#            'rank': 2,
#            'sklearn_classifier': MLPClassifier(alpha=0.0017940473175767063, beta_1=0.999, beta_2=0.9,
#               early_stopping=True, hidden_layer_sizes=(101, 101),
#               learning_rate_init=0.0004684917334431039, max_iter=32,
#               n_iter_no_change=32, random_state=1, verbose=0, warm_start=True)},
#     7: {   'balancing': Balancing(random_state=1),
#            'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x75ade9b3aa30>,
#            'cost': 0.014184397163120588,
#            'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x75aea4e05070>,
#            'ensemble_weight': 0.02,
#            'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x75ade9b3a730>,
#            'model_id': 7,
#            'rank': 3,
#            'sklearn_classifier': ExtraTreesClassifier(max_features=34, min_samples_leaf=3, min_samples_split=11,
#                      n_estimators=512, n_jobs=1, random_state=1,
#                      warm_start=True)},
#     8: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#            'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x75ade9b59790>,
#            'cost': 0.03546099290780147,
#            'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x75ade9b3ccd0>,
#            'ensemble_weight': 0.02,
#            'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x75ade9c4a160>,
#            'model_id': 8,
#            'rank': 4,
#            'sklearn_classifier': RandomForestClassifier(max_features=2, min_samples_leaf=2, n_estimators=512,
#                        n_jobs=1, random_state=1, warm_start=True)},
#     9: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#            'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x75ade9ad7dc0>,
#            'cost': 0.04255319148936165,
#            'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x75ade9c5c5b0>,
#            'ensemble_weight': 0.02,
#            'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x75ade9b99f10>,
#            'model_id': 9,
#            'rank': 5,
#            'sklearn_classifier': ExtraTreesClassifier(max_features=9, min_samples_split=10, n_estimators=512,
#                      n_jobs=1, random_state=1, warm_start=True)},
#     10: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x75ade9ad75e0>,
#             'cost': 0.028368794326241176,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x75ade9c231c0>,
#             'ensemble_weight': 0.04,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x75ade9ad7880>,
#             'model_id': 10,
#             'rank': 6,
#             'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=4, min_samples_split=6,
#                        n_estimators=512, n_jobs=1, random_state=1,
#                        warm_start=True)},
#     11: {   'balancing': Balancing(random_state=1),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x75ade12cbc10>,
#             'cost': 0.028368794326241176,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x75ade9b8af70>,
#             'ensemble_weight': 0.02,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x75ade12cb910>,
#             'model_id': 11,
#             'rank': 7,
#             'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=23, min_samples_leaf=7,
#                        n_estimators=512, n_jobs=1, random_state=1,
#                        warm_start=True)},
#     13: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x75ade10ba6a0>,
#             'cost': 0.028368794326241176,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x75ade9a1ca00>,
#             'ensemble_weight': 0.02,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x75ade10ba3a0>,
#             'model_id': 13,
#             'rank': 8,
#             'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=False,
#                                l2_regularization=1.0647401999412075e-10,
#                                learning_rate=0.08291320147381159, max_iter=512,
#                                max_leaf_nodes=39, n_iter_no_change=0,
#                                random_state=1, validation_fraction=None,
#                                warm_start=True)},
#     18: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x75ada9e92250>,
#             'cost': 0.03546099290780147,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x75ade1473f40>,
#             'ensemble_weight': 0.02,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x75adaa1e58b0>,
#             'model_id': 18,
#             'rank': 9,
#             'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, n_estimators=512,
#                        n_jobs=1, random_state=1, warm_start=True)},
#     21: {   'balancing': Balancing(random_state=1),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x75ada9e92130>,
#             'cost': 0.021276595744680882,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x75ade1190340>,
#             'ensemble_weight': 0.02,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x75ada9f0df10>,
#             'model_id': 21,
#             'rank': 10,
#             'sklearn_classifier': ExtraTreesClassifier(criterion='entropy', max_features=4, min_samples_leaf=2,
#                      min_samples_split=15, n_estimators=512, n_jobs=1,
#                      random_state=1, warm_start=True)},
#     22: {   'balancing': Balancing(random_state=1),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x75ada9cd9340>,
#             'cost': 0.028368794326241176,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x75adaa1d38e0>,
#             'ensemble_weight': 0.02,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x75ada9e18b80>,
#             'model_id': 22,
#             'rank': 11,
#             'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=8.057778875694463e-05,
#                                learning_rate=0.09179220974965213, max_iter=256,
#                                max_leaf_nodes=200, n_iter_no_change=18,
#                                random_state=1,
#                                validation_fraction=0.14295295806077554,
#                                warm_start=True)},
#     27: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x75ada9ad73d0>,
#             'cost': 0.014184397163120588,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x75adaa1e5e50>,
#             'ensemble_weight': 0.04,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x75ada9ad72e0>,
#             'model_id': 27,
#             'rank': 12,
#             'sklearn_classifier': ExtraTreesClassifier(max_features=134, min_samples_leaf=12, min_samples_split=4,
#                      n_estimators=512, n_jobs=1, random_state=1,
#                      warm_start=True)},
#     30: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x75ada9d39850>,
#             'cost': 0.021276595744680882,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x75ada9e92c40>,
#             'ensemble_weight': 0.02,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x75ada9d39b80>,
#             'model_id': 30,
#             'rank': 13,
#             'sklearn_classifier': ExtraTreesClassifier(max_features=5390, min_samples_leaf=7, n_estimators=512,
#                      n_jobs=1, random_state=1, warm_start=True)},
#     35: {   'balancing': Balancing(random_state=1),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x75ade9ab0dc0>,
#             'cost': 0.021276595744680882,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x75ada9e3cf40>,
#             'ensemble_weight': 0.02,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x75ade9b4a3a0>,
#             'model_id': 35,
#             'rank': 14,
#             'sklearn_classifier': LinearDiscriminantAnalysis(shrinkage='auto', solver='lsqr',
#                            tol=0.00015203326214769067)},
#     47: {   'balancing': Balancing(random_state=1),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x75ada961a430>,
#             'cost': 0.03546099290780147,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x75ada9ad7880>,
#             'ensemble_weight': 0.02,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x75ada961a190>,
#             'model_id': 47,
#             'rank': 15,
#             'sklearn_classifier': LinearDiscriminantAnalysis(shrinkage='auto', solver='lsqr',
#                            tol=1.9500089972795036e-05)},
#     48: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x75ada959dd00>,
#             'cost': 0.028368794326241176,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x75ada9d289a0>,
#             'ensemble_weight': 0.06,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x75ada959dac0>,
#             'model_id': 48,
#             'rank': 16,
#             'sklearn_classifier': ExtraTreesClassifier(criterion='entropy', max_features=1, min_samples_leaf=4,
#                      min_samples_split=4, n_estimators=512, n_jobs=1,
#                      random_state=1, warm_start=True)},
#     53: {   'balancing': Balancing(random_state=1),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x75ada9412190>,
#             'cost': 0.028368794326241176,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x75ada9738040>,
#             'ensemble_weight': 0.04,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x75ada94f3f70>,
#             'model_id': 53,
#             'rank': 17,
#             'sklearn_classifier': LinearDiscriminantAnalysis(shrinkage='auto', solver='lsqr',
#                            tol=0.010091049480872609)},
#     54: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x75ada91d2b50>,
#             'cost': 0.014184397163120588,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x75ada961ab80>,
#             'ensemble_weight': 0.04,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x75ada91d2970>,
#             'model_id': 54,
#             'rank': 18,
#             'sklearn_classifier': ExtraTreesClassifier(max_features=448, min_samples_leaf=7, min_samples_split=15,
#                      n_estimators=512, n_jobs=1, random_state=1,
#                      warm_start=True)},
#     57: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x75ada90ed8b0>,
#             'cost': 0.03546099290780147,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x75ada95439a0>,
#             'ensemble_weight': 0.06,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x75ada90ed4f0>,
#             'model_id': 57,
#             'rank': 19,
#             'sklearn_classifier': ExtraTreesClassifier(bootstrap=True, max_features=386, min_samples_leaf=18,
#                      min_samples_split=19, n_estimators=512, n_jobs=1,
#                      random_state=1, warm_start=True)},
#     60: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x75ada8d97af0>,
#             'cost': 0.03546099290780147,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x75ada9412730>,
#             'ensemble_weight': 0.02,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x75ada8d977f0>,
#             'model_id': 60,
#             'rank': 20,
#             'sklearn_classifier': PassiveAggressiveClassifier(C=0.20033416635429904, loss='squared_hinge',
#                             max_iter=64, random_state=1,
#                             tol=2.9056794240269816e-05, warm_start=True)},
#     61: {   'balancing': Balancing(random_state=1),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x75ada8b0dcd0>,
#             'cost': 0.03546099290780147,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x75ada910a670>,
#             'ensemble_weight': 0.02,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x75ada8d38670>,
#             'model_id': 61,
#             'rank': 21,
#             'sklearn_classifier': QuadraticDiscriminantAnalysis(reg_param=0.5903138018513074)},
#     71: {   'balancing': Balancing(random_state=1),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x75ada8b2f7f0>,
#             'cost': 0.03546099290780147,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x75ada9088d30>,
#             'ensemble_weight': 0.02,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x75ada8b2f670>,
#             'model_id': 71,
#             'rank': 22,
#             'sklearn_classifier': PassiveAggressiveClassifier(C=0.00021886840788969258, loss='squared_hinge',
#                             max_iter=256, random_state=1,
#                             tol=0.0006900149212352517, warm_start=True)},
#     73: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x75ada8afbb80>,
#             'cost': 0.021276595744680882,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x75ada8d4b1f0>,
#             'ensemble_weight': 0.02,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x75ada8afbac0>,
#             'model_id': 73,
#             'rank': 23,
#             'sklearn_classifier': AdaBoostClassifier(algorithm='SAMME',
#                    base_estimator=DecisionTreeClassifier(max_depth=3),
#                    learning_rate=0.4720844287915499, n_estimators=184,
#                    random_state=1)},
#     75: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x75ada906bd60>,
#             'cost': 0.014184397163120588,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x75ada8c72be0>,
#             'ensemble_weight': 0.04,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x75ada8cf2d90>,
#             'model_id': 75,
#             'rank': 24,
#             'sklearn_classifier': SVC(C=9.532297294578582, cache_size=10789.859375, class_weight='balanced',
#     gamma=0.3806127149882064, max_iter=-1.0, random_state=1,
#     tol=2.516055202264825e-05)},
#     80: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x75ade9b59f40>,
#             'cost': 0.014184397163120588,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x75ada8b2fd90>,
#             'ensemble_weight': 0.02,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x75ade9b99ee0>,
#             'model_id': 80,
#             'rank': 25,
#             'sklearn_classifier': ExtraTreesClassifier(max_features=18, min_samples_split=12, n_estimators=512,
#                      n_jobs=1, random_state=1, warm_start=True)},
#     85: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x75ade9a78820>,
#             'cost': 0.021276595744680882,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x75ada8a8f190>,
#             'ensemble_weight': 0.04,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x75adf1f0a6d0>,
#             'model_id': 85,
#             'rank': 26,
#             'sklearn_classifier': ExtraTreesClassifier(bootstrap=True, max_features=19, n_estimators=512,
#                      n_jobs=1, random_state=1, warm_start=True)},
#     86: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x75ada8232f40>,
#             'cost': 0.028368794326241176,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x75ada9746670>,
#             'ensemble_weight': 0.02,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x75ada8232400>,
#             'model_id': 86,
#             'rank': 27,
#             'sklearn_classifier': ExtraTreesClassifier(criterion='entropy', max_features=2, min_samples_leaf=3,
#                      min_samples_split=15, n_estimators=512, n_jobs=1,
#                      random_state=1, warm_start=True)},
#     88: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x75ada80fba00>,
#             'cost': 0.007092198581560294,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x75ade9a5f7f0>,
#             'ensemble_weight': 0.06,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x75ada80fb640>,
#             'model_id': 88,
#             'rank': 28,
#             'sklearn_classifier': ExtraTreesClassifier(bootstrap=True, max_features=1447, min_samples_leaf=4,
#                      min_samples_split=20, n_estimators=512, n_jobs=1,
#                      random_state=1, warm_start=True)},
#     94: {   'balancing': Balancing(random_state=1),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x75ada3de6340>,
#             'cost': 0.007092198581560294,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x75ade9b4a730>,
#             'ensemble_weight': 0.04,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x75ada3e49f40>,
#             'model_id': 94,
#             'rank': 29,
#             'sklearn_classifier': ExtraTreesClassifier(max_features=399, min_samples_leaf=3, min_samples_split=9,
#                      n_estimators=512, n_jobs=1, random_state=1,
#                      warm_start=True)},
#     108: {   'balancing': Balancing(random_state=1),
#              'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x75ada3ca0a60>,
#              'cost': 0.007092198581560294,
#              'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x75ada81dbb20>,
#              'ensemble_weight': 0.12,
#              'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x75ada3ca06a0>,
#              'model_id': 108,
#              'rank': 30,
#              'sklearn_classifier': ExtraTreesClassifier(bootstrap=True, max_features=1356, min_samples_split=18,
#                      n_estimators=512, n_jobs=1, random_state=1,
#                      warm_start=True)}}

# %% [markdown]
# ## Get the Score of the final ensemble

# %%
predictions = automl.predict(X_test)
print("Accuracy score:", sklearn.metrics.accuracy_score(y_test, predictions))
# Out:
# Accuracy score: 0.951048951048951
