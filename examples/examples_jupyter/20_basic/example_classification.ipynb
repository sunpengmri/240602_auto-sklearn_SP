# %%
# %matplotlib inline

# %% [markdown]
# # Classification
#
# The following example shows how to fit a simple classification model with
# *auto-sklearn*.

# %%
from pprint import pprint

import sklearn.datasets
import sklearn.metrics
from sklearn import model_selection
import autosklearn.classification
# Out:
# /home/peng/opt/anaconda3/envs/autosl/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /home/peng/.local/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.0' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# ## Data Loading

# %%
X, y = sklearn.datasets.load_breast_cancer(return_X_y=True)
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(
    X, y, random_state=1
)

# %% [markdown]
# ## Build and fit a classifier

# %%
automl = autosklearn.classification.AutoSklearnClassifier(
    time_left_for_this_task=120,
    per_run_time_limit=30,
    memory_limit=16384,
    tmp_folder="/tmp/autosklearn_classification_example_tmp",
)
automl.fit(X_train, y_train, dataset_name="breast_cancer")
# Out:
# AutoSklearnClassifier(ensemble_class=<class 'autosklearn.ensembles.ensemble_selection.EnsembleSelection'>,
#                       memory_limit=16384, per_run_time_limit=30,
#                       time_left_for_this_task=120,
#                       tmp_folder='/tmp/autosklearn_classification_example_tmp')

# %% [markdown]
# ## View the models found by auto-sklearn

# %%
print(automl.leaderboard())
# Out:
#           rank  ensemble_weight                type      cost  duration
# model_id
# 88           1             0.02         extra_trees  0.007092  1.435708
# 94           2             0.04         extra_trees  0.007092  0.909260
# 7            3             0.16         extra_trees  0.014184  0.457476
# 27           7             0.02         extra_trees  0.014184  0.671277
# 54           8             0.04         extra_trees  0.014184  0.922577
# 75           6             0.04          libsvm_svc  0.014184  0.402562
# 80           5             0.02         extra_trees  0.014184  0.500242
# 81           4             0.02          libsvm_svc  0.014184  0.325119
# 16          10             0.02   gradient_boosting  0.021277  0.352964
# 21          11             0.02         extra_trees  0.021277  0.424522
# 30          13             0.04         extra_trees  0.021277  5.059915
# 35          15             0.02                 lda  0.021277  0.293250
# 70          14             0.02         extra_trees  0.021277  0.880912
# 73          12             0.02            adaboost  0.021277  0.682336
# 92           9             0.02         extra_trees  0.021277  4.230011
# 2           16             0.02       random_forest  0.028369  0.528985
# 13          20             0.04   gradient_boosting  0.028369  0.458724
# 19          19             0.04         extra_trees  0.028369  0.999791
# 22          18             0.04   gradient_boosting  0.028369  0.365862
# 40          17             0.02         extra_trees  0.028369  0.580555
# 53          21             0.04                 lda  0.028369  0.258445
# 97          22             0.02  passive_aggressive  0.028369  0.254576
# 5           28             0.02       random_forest  0.035461  0.576654
# 18          27             0.02       random_forest  0.035461  0.567940
# 31          25             0.02       random_forest  0.035461  0.488190
# 45          23             0.04         extra_trees  0.035461  0.455280
# 60          24             0.10  passive_aggressive  0.035461  0.359008
# 71          26             0.04  passive_aggressive  0.035461  0.374112
# 9           29             0.02         extra_trees  0.042553  0.535629

# %% [markdown]
# ## Print the final ensemble constructed by auto-sklearn

# %%
pprint(automl.show_models(), indent=4)
# Out:
# {   2: {   'balancing': Balancing(random_state=1),
#            'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7bbd5de9edc0>,
#            'cost': 0.028368794326241176,
#            'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7bbd5df747f0>,
#            'ensemble_weight': 0.02,
#            'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7bbde29fcca0>,
#            'model_id': 2,
#            'rank': 1,
#            'sklearn_classifier': RandomForestClassifier(max_features=5, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)},
#     5: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#            'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7bbd287a14c0>,
#            'cost': 0.03546099290780147,
#            'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7bbd5df74cd0>,
#            'ensemble_weight': 0.02,
#            'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7bbd5ddf97c0>,
#            'model_id': 5,
#            'rank': 2,
#            'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, min_samples_leaf=2,
#                        n_estimators=512, n_jobs=1, random_state=1,
#                        warm_start=True)},
#     7: {   'balancing': Balancing(random_state=1),
#            'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7bbd287a1100>,
#            'cost': 0.014184397163120588,
#            'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7bbd5de69eb0>,
#            'ensemble_weight': 0.16,
#            'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7bbd28734c40>,
#            'model_id': 7,
#            'rank': 3,
#            'sklearn_classifier': ExtraTreesClassifier(max_features=34, min_samples_leaf=3, min_samples_split=11,
#                      n_estimators=512, n_jobs=1, random_state=1,
#                      warm_start=True)},
#     9: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#            'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7bbd290627f0>,
#            'cost': 0.04255319148936165,
#            'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7bbd5df2a100>,
#            'ensemble_weight': 0.02,
#            'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7bbd2949a0d0>,
#            'model_id': 9,
#            'rank': 4,
#            'sklearn_classifier': ExtraTreesClassifier(max_features=9, min_samples_split=10, n_estimators=512,
#                      n_jobs=1, random_state=1, warm_start=True)},
#     13: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7bbd290621f0>,
#             'cost': 0.028368794326241176,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7bbd44c7ddc0>,
#             'ensemble_weight': 0.04,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7bbd29062100>,
#             'model_id': 13,
#             'rank': 5,
#             'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=False,
#                                l2_regularization=1.0647401999412075e-10,
#                                learning_rate=0.08291320147381159, max_iter=512,
#                                max_leaf_nodes=39, n_iter_no_change=0,
#                                random_state=1, validation_fraction=None,
#                                warm_start=True)},
#     16: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7bbd27f96be0>,
#             'cost': 0.021276595744680882,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7bbd2912de50>,
#             'ensemble_weight': 0.02,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7bbd27f96ac0>,
#             'model_id': 16,
#             'rank': 6,
#             'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=3.387912939529945e-10,
#                                learning_rate=0.30755227194768237, max_iter=128,
#                                max_leaf_nodes=60, min_samples_leaf=39,
#                                n_iter_no_change=18, random_state=1,
#                                validation_fraction=None, warm_start=True)},
#     18: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7bbd1fcbba30>,
#             'cost': 0.03546099290780147,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7bbd2913b040>,
#             'ensemble_weight': 0.02,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7bbd1fd87190>,
#             'model_id': 18,
#             'rank': 7,
#             'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=3, n_estimators=512,
#                        n_jobs=1, random_state=1, warm_start=True)},
#     19: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7bbd1fcbbb20>,
#             'cost': 0.028368794326241176,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7bbd27f92b20>,
#             'ensemble_weight': 0.04,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7bbd1fcbb850>,
#             'model_id': 19,
#             'rank': 8,
#             'sklearn_classifier': ExtraTreesClassifier(criterion='entropy', max_features=448, min_samples_leaf=2,
#                      min_samples_split=20, n_estimators=512, n_jobs=1,
#                      random_state=1, warm_start=True)},
#     21: {   'balancing': Balancing(random_state=1),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7bbd1fbe5700>,
#             'cost': 0.021276595744680882,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7bbd27e1c100>,
#             'ensemble_weight': 0.02,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7bbd1fbe5340>,
#             'model_id': 21,
#             'rank': 9,
#             'sklearn_classifier': ExtraTreesClassifier(criterion='entropy', max_features=4, min_samples_leaf=2,
#                      min_samples_split=15, n_estimators=512, n_jobs=1,
#                      random_state=1, warm_start=True)},
#     22: {   'balancing': Balancing(random_state=1),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7bbd1f8b0b20>,
#             'cost': 0.028368794326241176,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7bbd1fd87820>,
#             'ensemble_weight': 0.04,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7bbd1fa84e20>,
#             'model_id': 22,
#             'rank': 10,
#             'sklearn_classifier': HistGradientBoostingClassifier(early_stopping=True,
#                                l2_regularization=8.057778875694463e-05,
#                                learning_rate=0.09179220974965213, max_iter=256,
#                                max_leaf_nodes=200, n_iter_no_change=18,
#                                random_state=1,
#                                validation_fraction=0.14295295806077554,
#                                warm_start=True)},
#     27: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7bbd1f8b08e0>,
#             'cost': 0.014184397163120588,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7bbd1fc5d4c0>,
#             'ensemble_weight': 0.02,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7bbd1f8b0520>,
#             'model_id': 27,
#             'rank': 11,
#             'sklearn_classifier': ExtraTreesClassifier(max_features=134, min_samples_leaf=12, min_samples_split=4,
#                      n_estimators=512, n_jobs=1, random_state=1,
#                      warm_start=True)},
#     30: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7bbd1f56b6a0>,
#             'cost': 0.021276595744680882,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7bbd1fb8ab80>,
#             'ensemble_weight': 0.04,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7bbd1f56b4c0>,
#             'model_id': 30,
#             'rank': 12,
#             'sklearn_classifier': ExtraTreesClassifier(max_features=5390, min_samples_leaf=7, n_estimators=512,
#                      n_jobs=1, random_state=1, warm_start=True)},
#     31: {   'balancing': Balancing(random_state=1),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7bbd173d3640>,
#             'cost': 0.03546099290780147,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7bbd1fa10340>,
#             'ensemble_weight': 0.02,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7bbd173d31c0>,
#             'model_id': 31,
#             'rank': 13,
#             'sklearn_classifier': RandomForestClassifier(criterion='entropy', max_features=2, min_samples_leaf=10,
#                        min_samples_split=7, n_estimators=512, n_jobs=1,
#                        random_state=1, warm_start=True)},
#     35: {   'balancing': Balancing(random_state=1),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7bbd17282a00>,
#             'cost': 0.021276595744680882,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7bbd1f647340>,
#             'ensemble_weight': 0.02,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7bbd17282640>,
#             'model_id': 35,
#             'rank': 14,
#             'sklearn_classifier': LinearDiscriminantAnalysis(shrinkage='auto', solver='lsqr',
#                            tol=0.00015203326214769067)},
#     40: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7bbd168d0940>,
#             'cost': 0.028368794326241176,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7bbd1f4e21f0>,
#             'ensemble_weight': 0.02,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7bbd168d0580>,
#             'model_id': 40,
#             'rank': 15,
#             'sklearn_classifier': ExtraTreesClassifier(criterion='entropy', max_features=13, min_samples_leaf=16,
#                      n_estimators=512, n_jobs=1, random_state=1,
#                      warm_start=True)},
#     45: {   'balancing': Balancing(random_state=1),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7bbd15ec6df0>,
#             'cost': 0.03546099290780147,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7bbd173f57c0>,
#             'ensemble_weight': 0.04,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7bbd15ec6a30>,
#             'model_id': 45,
#             'rank': 16,
#             'sklearn_classifier': ExtraTreesClassifier(max_features=34, min_samples_leaf=13, min_samples_split=5,
#                      n_estimators=512, n_jobs=1, random_state=1,
#                      warm_start=True)},
#     53: {   'balancing': Balancing(random_state=1),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7bbd287820a0>,
#             'cost': 0.028368794326241176,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7bbd169a4700>,
#             'ensemble_weight': 0.04,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7bbd28778550>,
#             'model_id': 53,
#             'rank': 17,
#             'sklearn_classifier': LinearDiscriminantAnalysis(shrinkage='auto', solver='lsqr',
#                            tol=0.010091049480872609)},
#     54: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7bbcccae4d90>,
#             'cost': 0.014184397163120588,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7bbd1688c8b0>,
#             'ensemble_weight': 0.04,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7bbcccae49d0>,
#             'model_id': 54,
#             'rank': 18,
#             'sklearn_classifier': ExtraTreesClassifier(max_features=448, min_samples_leaf=7, min_samples_split=15,
#                      n_estimators=512, n_jobs=1, random_state=1,
#                      warm_start=True)},
#     60: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7bbccc922e20>,
#             'cost': 0.03546099290780147,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7bbd15eff430>,
#             'ensemble_weight': 0.1,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7bbccc922b20>,
#             'model_id': 60,
#             'rank': 19,
#             'sklearn_classifier': PassiveAggressiveClassifier(C=0.20033416635429904, loss='squared_hinge',
#                             max_iter=64, random_state=1,
#                             tol=2.9056794240269816e-05, warm_start=True)},
#     70: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7bbccc899b50>,
#             'cost': 0.021276595744680882,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7bbd29434df0>,
#             'ensemble_weight': 0.02,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7bbccc8998b0>,
#             'model_id': 70,
#             'rank': 20,
#             'sklearn_classifier': ExtraTreesClassifier(max_features=121, min_samples_leaf=6, min_samples_split=16,
#                      n_estimators=512, n_jobs=1, random_state=1,
#                      warm_start=True)},
#     71: {   'balancing': Balancing(random_state=1),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7bbccbf46c40>,
#             'cost': 0.03546099290780147,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7bbccca9ea30>,
#             'ensemble_weight': 0.04,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7bbccbf46940>,
#             'model_id': 71,
#             'rank': 21,
#             'sklearn_classifier': PassiveAggressiveClassifier(C=0.00021886840788969258, loss='squared_hinge',
#                             max_iter=256, random_state=1,
#                             tol=0.0006900149212352517, warm_start=True)},
#     73: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7bbccbec8880>,
#             'cost': 0.021276595744680882,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7bbccc93aa60>,
#             'ensemble_weight': 0.02,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7bbccbec8700>,
#             'model_id': 73,
#             'rank': 22,
#             'sklearn_classifier': AdaBoostClassifier(algorithm='SAMME',
#                    base_estimator=DecisionTreeClassifier(max_depth=3),
#                    learning_rate=0.4720844287915499, n_estimators=184,
#                    random_state=1)},
#     75: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7bbcc814cb50>,
#             'cost': 0.014184397163120588,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7bbccc87f730>,
#             'ensemble_weight': 0.04,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7bbcc814c790>,
#             'model_id': 75,
#             'rank': 23,
#             'sklearn_classifier': SVC(C=9.532297294578582, cache_size=10736.088541666666, class_weight='balanced',
#     gamma=0.3806127149882064, max_iter=-1.0, random_state=1,
#     tol=2.516055202264825e-05)},
#     80: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7bbcc80c84f0>,
#             'cost': 0.014184397163120588,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7bbccbf6b7c0>,
#             'ensemble_weight': 0.02,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7bbcc80c8400>,
#             'model_id': 80,
#             'rank': 24,
#             'sklearn_classifier': ExtraTreesClassifier(max_features=18, min_samples_split=12, n_estimators=512,
#                      n_jobs=1, random_state=1, warm_start=True)},
#     81: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7bbcc35f00d0>,
#             'cost': 0.014184397163120588,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7bbccbeb2580>,
#             'ensemble_weight': 0.02,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7bbcc3fbdf10>,
#             'model_id': 81,
#             'rank': 25,
#             'sklearn_classifier': SVC(C=4.358171042742106, cache_size=10740.255208333334, class_weight='balanced',
#     gamma=0.027894730725949512, max_iter=-1.0, random_state=1, shrinking=False,
#     tol=0.0001292564850933418)},
#     88: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7bbcc2b9ba30>,
#             'cost': 0.007092198581560294,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7bbcc816b6d0>,
#             'ensemble_weight': 0.02,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7bbcc2b9b850>,
#             'model_id': 88,
#             'rank': 26,
#             'sklearn_classifier': ExtraTreesClassifier(bootstrap=True, max_features=1447, min_samples_leaf=4,
#                      min_samples_split=20, n_estimators=512, n_jobs=1,
#                      random_state=1, warm_start=True)},
#     92: {   'balancing': Balancing(random_state=1, strategy='weighting'),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7bbcc2a63910>,
#             'cost': 0.021276595744680882,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7bbcc80c8be0>,
#             'ensemble_weight': 0.02,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7bbcc2a63550>,
#             'model_id': 92,
#             'rank': 27,
#             'sklearn_classifier': ExtraTreesClassifier(criterion='entropy', max_features=3096, min_samples_leaf=7,
#                      min_samples_split=17, n_estimators=512, n_jobs=1,
#                      random_state=1, warm_start=True)},
#     94: {   'balancing': Balancing(random_state=1),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7bbcc20b0f70>,
#             'cost': 0.007092198581560294,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7bbcc35f0610>,
#             'ensemble_weight': 0.04,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7bbcc20b0bb0>,
#             'model_id': 94,
#             'rank': 28,
#             'sklearn_classifier': ExtraTreesClassifier(max_features=399, min_samples_leaf=3, min_samples_split=9,
#                      n_estimators=512, n_jobs=1, random_state=1,
#                      warm_start=True)},
#     97: {   'balancing': Balancing(random_state=1),
#             'classifier': <autosklearn.pipeline.components.classification.ClassifierChoice object at 0x7bbcc0d38760>,
#             'cost': 0.028368794326241176,
#             'data_preprocessor': <autosklearn.pipeline.components.data_preprocessing.DataPreprocessorChoice object at 0x7bbcc2aef610>,
#             'ensemble_weight': 0.02,
#             'feature_preprocessor': <autosklearn.pipeline.components.feature_preprocessing.FeaturePreprocessorChoice object at 0x7bbcc0d383a0>,
#             'model_id': 97,
#             'rank': 29,
#             'sklearn_classifier': PassiveAggressiveClassifier(C=0.09125658197166976, max_iter=64, random_state=1,
#                             tol=0.0005076149780308491, warm_start=True)}}

# %% [markdown]
# ## Get the Score of the final ensemble

# %%
predictions = automl.predict(X_test)
print("Accuracy score:", sklearn.metrics.accuracy_score(y_test, predictions))
# Out:
# Accuracy score: 0.951048951048951
